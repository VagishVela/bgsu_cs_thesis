# %%
import pubmed_parser as pp
import pandas as pd
import nltk
nltk.download('punkt')
import numpy as np
from csv import DictWriter
import json
import math

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#Source: https://stackoverflow.com/questions/12118720/python-tf-idf-cosine-to-find-document-similarity
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vagishvela/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
path_xml = pp.list_xml_path('../../data/raw') # list all xml paths under directory
pubmed_dict = pp.parse_medline_xml(path_xml[0]) # dictionary output

# %%
df = pd.DataFrame(pubmed_dict)
df.head()
# Out:
#                                                title   issue   pages abstract  \
# 0  [Beta-blockers and arterial hypertension in th...   7(31)  2807-9
# 1  [beta-blockers and high risk pregnancies. View...   7(31)  2811-2
# 2  [Surface defense mechanisms of the nasal mucosa].  33(35)  1391-3
# 3   [Pharmacological treatment of coronary disease].  33(44)  1721-4
# 4             Treating the outpatient schizophrenic.   64(5)   48-56
#
#                                             journal  \
# 0                       La Nouvelle presse medicale
# 1                       La Nouvelle presse medicale
# 2  Polski tygodnik lekarski (Warsaw, Poland : 1960)
# 3  Polski tygodnik lekarski (Warsaw, Poland : 1960)
# 4                             Postgraduate medicine
#
#                        authors pubdate   pmid  \
# 0             Tcherdakoff|P|P|    1978  30970
# 1  Dubois|D|D|;Petitcolas|J|J|    1978  30971
# 2   Makowska|W|W|;Zawisza|E|E|    1978  30972
# 3             Krotkiewski|A|A|    1978  30973
# 4            Gelenberg|A J|AJ|    1978  30974
#
#                                           mesh_terms  \
# 0  D000319:Adrenergic beta-Antagonists; D005260:F...
# 1  D000070:Acebutolol; D000319:Adrenergic beta-An...
# 2  D001424:Bacterial Infections; D002633:Chemotax...
# 3  D000319:Adrenergic beta-Antagonists; D003327:C...
# 4  D000208:Acute Disease; D000553:Ambulatory Care...
#
#                          publication_types  ...  \
# 0                  D016428:Journal Article  ...
# 1                  D016428:Journal Article  ...
# 2  D016428:Journal Article; D016454:Review  ...
# 3                  D016428:Journal Article  ...
# 4                  D016428:Journal Article  ...
#
#                               doi references delete affiliations  pmc  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4  10.1080/00325481.1978.11714969             False
#
#   other_id       medline_ta nlm_unique_id issn_linking  country
# 0           Nouv Presse Med       0312552    0301-1518   France
# 1           Nouv Presse Med       0312552    0301-1518   France
# 2               Pol Tyg Lek       9705468    0032-3756   Poland
# 3               Pol Tyg Lek       9705468    0032-3756   Poland
# 4              Postgrad Med       0401147    0032-5481  England
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              30000 non-null  object
#  1   issue              30000 non-null  object
#  2   pages              30000 non-null  object
#  3   abstract           30000 non-null  object
#  4   journal            30000 non-null  object
#  5   authors            30000 non-null  object
#  6   pubdate            30000 non-null  object
#  7   pmid               30000 non-null  object
#  8   mesh_terms         30000 non-null  object
#  9   publication_types  30000 non-null  object
#  10  chemical_list      30000 non-null  object
#  11  keywords           30000 non-null  object
#  12  doi                30000 non-null  object
#  13  references         30000 non-null  object
#  14  delete             30000 non-null  bool
#  15  affiliations       30000 non-null  object
#  16  pmc                30000 non-null  object
#  17  other_id           30000 non-null  object
#  18  medline_ta         30000 non-null  object
#  19  nlm_unique_id      30000 non-null  object
#  20  issn_linking       30000 non-null  object
#  21  country            30000 non-null  object
# dtypes: bool(1), object(21)
# memory usage: 4.8+ MB

# %%
abstractDf = df.drop(df[df['abstract'] == ''].index)

# %%
abstractDf
# Out:
#                                                    title    issue   pages  \
# 10     [Isolation and properties of preparations the ...    14(5)   683-9
# 11     Potentiation of apomorphine action in rats by ...     9(3)   375-8
# 14     Specific immune recognition by lymphocytes: an...    53(3)  225-41
# 19     An analysis of measured and calculated calcium...    38(7)  659-67
# 20     The value of immunoelectroosmophoresis (IEOP) ...    10(3)   173-6
# ...                                                  ...      ...     ...
# 29964                      Pregnancy hepatitis in Libya.  2(7990)   827-9
# 29965  Oral methionine in the treatment of severe par...  2(7990)  829-30
# 29966  Integrated concentrations of catecholamines in...  2(7990)   830-1
# 29967  The neurology of vitamin B12 deficiency. Metab...  2(7990)   832-3
# 29977  Measuring partial thromboplastin-time. An inte...  2(7990)   842-6
#
#                                                 abstract  \
# 10     The paper describes a modified method of isola...
# 11     Although the antiparkinsonian activity of 1-pr...
# 14     In this review, we analyze data pertinent to t...
# 19     Potentiometrically measured ionized calcium (C...
# 20     Immunoelectroosmophoresis (IEOP) has been used...
# ...                                                  ...
# 29964  The death-rate from hepatitis in pregnant wome...
# 29965  30 patients at risk of hepatic damage from par...
# 29966  The measurement of integrated concentrations o...
# 29967  The widely held view that the neurological and...
# 29977  A series of collaborative exercises on the par...
#
#                                                  journal  \
# 10               Prikladnaia biokhimiia i mikrobiologiia
# 11              Pharmacology, biochemistry, and behavior
# 14                       The Quarterly review of biology
# 19     Scandinavian journal of clinical and laborator...
# 20           Scandinavian journal of infectious diseases
# ...                                                  ...
# 29964                           Lancet (London, England)
# 29965                           Lancet (London, England)
# 29966                           Lancet (London, England)
# 29967                           Lancet (London, England)
# 29977                           Lancet (London, England)
#
#                                                  authors pubdate   pmid  \
# 10                      Shvedova|T A|TA|;Petrova|A N|AN|    1978  30978
# 11      Kostrzewa|R M|RM|;Kastin|A J|AJ|;Sobrian|S K|SK|    1978  30981
# 14                      Warr|G W|GW|;Marchalonis|J J|JJ|    1978  30984
# 19                                      Pedersen|K O|KO|    1978  30989
# 20             Wiernik|A|A|;Jarstrand|C|C|;Tunevall|G|G|    1978  30990
# ...                                                  ...     ...    ...
# 29964  Christie|A B|AB|;Allam|A A|AA|;Aref|M K|MK|;Mu...    1976  61499
# 29965  Crome|P|P|;Vale|J A|JA|;Volans|G N|GN|;Widdop|...    1976  61500
# 29966                                       Daggett|P|P|    1976  61501
# 29967                                   Reynolds|E H|EH|    1976  61502
# 29977                        Poller|L|L|;Thomson|J M|JM|    1976  61512
#
#                                               mesh_terms  \
# 10     D015061:1,4-alpha-Glucan Branching Enzyme; D00...
# 11     D000818:Animals; D001058:Apomorphine; D001522:...
# 14     D000220:Adaptation, Biological; D000818:Animal...
# 19     D000293:Adolescent; D000328:Adult; D000367:Age...
# 20     D000900:Anti-Bacterial Agents; D000942:Antigen...
# ...                                                  ...
# 29964  D000293:Adolescent; D000328:Adult; D005260:Fem...
# 29965  D000082:Acetaminophen; D000284:Administration,...
# 29966  D000310:Adrenal Gland Neoplasms; D001794:Blood...
# 29967  D000752:Anemia, Pernicious; D005492:Folic Acid...
# 29977  D001778:Blood Coagulation Disorders; D001780:B...
#
#                                        publication_types  ...  \
# 10     D003160:Comparative Study; D004740:English Abs...  ...
# 11     D003160:Comparative Study; D016428:Journal Art...  ...
# 14     D016428:Journal Article; D013487:Research Supp...  ...
# 19                               D016428:Journal Article  ...
# 20                               D016428:Journal Article  ...
# ...                                                  ...  ...
# 29964  D003160:Comparative Study; D016428:Journal Art...  ...
# 29965  D003160:Comparative Study; D016428:Journal Art...  ...
# 29966                            D016428:Journal Article  ...
# 29967                            D016428:Journal Article  ...
# 29977  D003160:Comparative Study; D016428:Journal Art...  ...
#
#                                   doi references delete affiliations  pmc  \
# 10                                                False
# 11       10.1016/0091-3057(78)90299-x             False
# 14                     10.1086/410621             False
# 19          10.3109/00365517809102433             False
# 20     10.3109/inf.1978.10.issue-3.03             False
# ...                               ...        ...    ...          ...  ...
# 29964   10.1016/s0140-6736(76)91210-1             False
# 29965   10.1016/s0140-6736(76)91211-3             False
# 29966   10.1016/s0140-6736(76)91212-5             False
# 29967   10.1016/s0140-6736(76)91213-7             False
# 29977   10.1016/s0140-6736(76)91224-1             False
#
#                other_id               medline_ta nlm_unique_id issn_linking  \
# 10                       Prikl Biokhim Mikrobiol       0023416    0555-1099
# 11                       Pharmacol Biochem Behav       0367050    0091-3057
# 14                                    Q Rev Biol       0376515    0033-5770
# 19                       Scand J Clin Lab Invest       0404375    0036-5513
# 20                            Scand J Infect Dis       0215333    0036-5548
# ...                 ...                      ...           ...          ...
# 29964  054851; 00198778                   Lancet      2985213R    0140-6736
# 29965                                     Lancet      2985213R    0140-6736
# 29966                                     Lancet      2985213R    0140-6736
# 29967                                     Lancet      2985213R    0140-6736
# 29977                                     Lancet      2985213R    0140-6736
#
#                    country
# 10     Russia (Federation)
# 11           United States
# 14           United States
# 19                 England
# 20                 England
# ...                    ...
# 29964              England
# 29965              England
# 29966              England
# 29967              England
# 29977              England
#
# [13415 rows x 22 columns]

# %%
vectorizer = TfidfVectorizer()

# %%
abstracts_tfidf = vectorizer.fit_transform(abstracts)

# %%
def get_consine_similarity_tf_idf(vectorizer,abstracts_tfidf, query):
    query_tfidf = vectorizer.transform([query])
    cosine_similarities = cosine_similarity(query_tfidf, abstracts_tfidf).flatten()
    return cosine_similarities

# %%
def get_top_n_cosine_similarity_tf_idf_docs(vectorizer, abstracts_tfidf, query, n=10):
    cosine_similarities = get_consine_similarity_tf_idf(vectorizer,abstracts_tfidf, query)
    related_docs_indices = cosine_similarities.argsort()[:-n - 1:-1]
    return [(index, cosine_similarities[index]) for index in related_docs_indices]

# %%
def get_top_n_nlm_ids_cosine_similarity_tf_idf_docs(vectorizer, abstracts_tfidf, query, n=10):
    related_docs_indices = get_top_n_cosine_similarity_tf_idf_docs(vectorizer, abstracts_tfidf, query, n)
    return [(nlm_ids[index], score) for index, score in related_docs_indices]

# %%
def get_full_nlm_docs_cosine_similarity_tf_idf_docs(vectorizer, abstracts_tfidf, query, n=10):
    related_docs_indices = get_top_n_cosine_similarity_tf_idf_docs(vectorizer, abstracts_tfidf, query, n)
    return [(pubmed_dict[index], score) for index, score in related_docs_indices]

# %%
get_full_nlm_docs_cosine_similarity_tf_idf_docs(vectorizer, abstracts_tfidf, 'phosphoenzyme')
# Out:
# [({'title': 'Ca2+-Ca2+ exchange catalyzed by the membrane-bound Ca2+, Mg2+-ATPase of sarcoplasmic reticulum vesicles.',
#    'issue': '24()',
#    'pages': '423-34',
#    'abstract': 'Sarcoplasmic reticulum vesicles were preloaded with either 45Ca2+ or unlabeled Ca2+ X 45Ca2+ efflux and influx, together with phosphorylation of the membrane-bound Ca2+, Mg2+-ATPase, were determined in the presence of either ATP and ADP or acetyl phosphate. ATP induced 45Ca2+ efflux. This ATP-induced 45Ca2+ efflux depended on ADP, external Ca2+, and Mg2+. The Ca2+ concentration dependence of the efflux was quite similar to the Ca2+ concentration dependence of the ATP-induced 45Ca2+ influx and the enzyme phosphorylation. The rate of the efflux was proportional to the steady level of the phosphoenzyme. The affinity for free ADP in this efflux was extremely high, being in good agreement with the affinity for free ADP in the transphosphorylation from the phosphoenzyme to ADP. These results show that the ATP-induced 45Ca2+ efflux represents the Ca2+-Ca2+ exchange (between the external medium and the internal medium) mediated by the phosphoenzyme. In this exchange, Mg2+ was essential for the exposure of the bound Ca2+ of the phosphoenzyme to the internal medium. 45Ca2+ efflux and influx were also activated by acetyl phosphate. This acetyl phosphate-induced efflux required the external Ca2+. The Ca2+ concentration dependence of the efflux agreed closely with that of the enzyme phosphorylation by acetyl phosphate. Furthermore, the rate of the efflux was proportional to the steady level of the phosphoenzyme. These and other findings show that the acetyl phosphate-induced 45Ca2+ efflux represents the Ca2+-Ca2+ exchange mediated by the phosphoenzyme and further demonstrate the direct dissociation of Ca2+ from the Ca2+-bound phosphoenzyme to the external medium in this Ca2+-Ca2+ exchange. The rate of the acetyl phosphate-induced, phosphoenzyme-mediated Ca2+ efflux was much slower than that of the ATP-, ADP-induced, phosphoenzyme-mediated Ca2+ efflux. This is consistent with our previous conclusion that the Ca2+ binding site is partially occluded upon the phosphorylation of the enzyme.',
#    'journal': 'Current topics in cellular regulation',
#    'authors': 'Kanazawa|T|T|;Takakuwa|Y|Y|',
#    'pubdate': '1984',
#    'pmid': '6149890',
#    'mesh_terms': 'D000818:Animals; D017301:Ca(2+) Mg(2+)-ATPase; D002118:Calcium; D002132:Calcium Radioisotopes; D000252:Calcium-Transporting ATPases; D007700:Kinetics; D009132:Muscles; D010755:Organophosphates; D010766:Phosphorylation; D011817:Rabbits; D012519:Sarcoplasmic Reticulum',
#    'publication_types': 'D016428:Journal Article',
#    'chemical_list': 'D002132:Calcium Radioisotopes; D010755:Organophosphates; C011632:acetyl phosphate; D017301:Ca(2+) Mg(2+)-ATPase; D000252:Calcium-Transporting ATPases; D002118:Calcium',
#    'keywords': '',
#    'doi': '10.1016/b978-0-12-152824-9.50044-7',
#    'references': '',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Curr Top Cell Regul',
#    'nlm_unique_id': '2984740R',
#    'issn_linking': '0070-2137',
#    'country': 'United States'},
#   0.4033874387734705),
#  ({'title': 'Hyperthyroidism complicating pregnancy: results of treatment by antithyroid drugs in 77 pregnancies.',
#    'issue': '87(11)',
#    'pages': '970-5',
#    'abstract': 'Seventy-seven pregnancies (79 infants) complicated by hyperthyroidism were seen at three Dublin Maternity Hospitals during a 25 year period. Hyperthyroidism was diagnosed following conception in 14 pregnancies. Treatment was with carbimazole alone in 73 pregnancies, in a usual dose of 5 to 10 mg daily. The total fetal loss was 15.2 per cent with a perinatal loss of 5.1 per cent. The perinatal loss in patients treated with carbimazole alone was 4.1 per cent (excluding one death due to congenital malformation). Four infants (5.1 per cent) had goitre and 57 (85.1 per cent) of the surviving infants were above the 25th centile for gestational age. Spontaneous premature labour occurred in 7 pregnancies (9.1 per cent). There was a relative excess of infants with a birth weight less than the 25th centile, of neonatal goitre and premature labour after pregnancy in which treatment was started following conception. Hyperthyroidism complicating pregnancy can be treated effectively with antithyroid drugs given alone and in the minimal effective dose.',
#    'journal': 'British journal of obstetrics and gynaecology',
#    'authors': 'Sugrue|D|D|;Drury|M I|MI|',
#    'pubdate': '1980',
#    'pmid': '6159916',
#    'mesh_terms': 'D013956:Antithyroid Agents; D001724:Birth Weight; D002231:Carbimazole; D005260:Female; D005313:Fetal Death; D006042:Goiter; D006801:Humans; D006980:Hyperthyroidism; D007231:Infant, Newborn; D007232:Infant, Newborn, Diseases; D011247:Pregnancy; D011248:Pregnancy Complications',
#    'publication_types': "D016428:Journal Article; D013485:Research Support, Non-U.S. Gov't",
#    'chemical_list': 'D013956:Antithyroid Agents; D002231:Carbimazole',
#    'keywords': '',
#    'doi': '10.1111/j.1471-0528.1980.tb04460.x',
#    'references': '',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Br J Obstet Gynaecol',
#    'nlm_unique_id': '7503752',
#    'issn_linking': '0306-5456',
#    'country': 'England'},
#   0.0),
#  ({'title': 'Toxicology studies of fenbufen.',
#    'issue': '30(4A)',
#    'pages': '721-5',
#    'abstract': "The acute, subacute, and chronic toxicity of gamma-oxo[1,1'-biphenyl]-4-butanoic acid (fenbufen), a new orally and parenterally effective non-steroidal antiinflammatory, analgesic, and antipyretic agent, was investigated in mice, rats, and dogs. In these studies, the gastrointestinal and renal changes associated with toxic doses of fenbufen resembled those described for this class of drug. In coadministration studies, there were no evidences of specific adverse interactions when fenbufen was given with dicoumarol or with triamcinolone; however, coadministration of acetylsalicylic acid (ASA) and fenbufen resulted in decreased plasma concentrations of fenbufen-related materials and a possible increase in the incidence of gastrointestinal hemorrhages or ulcers.",
#    'journal': 'Arzneimittel-Forschung',
#    'authors': 'Bolte|H F|HF|;Koralek|A V|AV|;Traitor|C E|CE|',
#    'pubdate': '1980',
#    'pmid': '6159904',
#    'mesh_terms': 'D000818:Animals; D000893:Anti-Inflammatory Agents; D001241:Aspirin; D001713:Biphenyl Compounds; D001728:Dicumarol; D004347:Drug Interactions; D005260:Female; D008297:Male; D051379:Mice; D010654:Phenylbutyrates; D011422:Propionates; D051381:Rats; D013045:Species Specificity; D013997:Time Factors; D014221:Triamcinolone',
#    'publication_types': 'D016428:Journal Article',
#    'chemical_list': 'D000893:Anti-Inflammatory Agents; D001713:Biphenyl Compounds; D010654:Phenylbutyrates; D011422:Propionates; D014221:Triamcinolone; D001728:Dicumarol; C010725:fenbufen; D001241:Aspirin',
#    'keywords': '',
#    'doi': '',
#    'references': '',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Arzneimittelforschung',
#    'nlm_unique_id': '0372660',
#    'issn_linking': '0004-4172',
#    'country': 'Germany'},
#   0.0),
#  ({'title': 'Extracorporeal interferon therapy in malignant melanoma. Significant economies of interferon in an extracorporeal chamber.',
#    'issue': '30(8)',
#    'pages': '1245-6',
#    'abstract': 'A new method is described for interferon therapy. The procedure involves immobilization of interferon with maintained activity to the surfaces of an extracorporeal perfusion chamber made from polymethylmethacrylate, having a surface area of 0.5 m2 and housing 150 ml blood. The interferon activity remains for at least 3 weeks in a chamber used in patients. Three cases of malignant melanoma, stage II, were treated for 35 to 50 h. The treatment induced increased natural killer activity against melanoma target cells (cytotoxicity index +45--65%) which lasted even after cessation of therapy. the drastic reduction in costs for this type of interferon therapy is underlined.',
#    'journal': 'Arzneimittel-Forschung',
#    'authors': 'Langvad|E|E|;Hydén|H|H|;Petersen|J K|JK|;Jordal|R|R|;Olsen|G|G|',
#    'pubdate': '1980',
#    'pmid': '6159905',
#    'mesh_terms': 'D003365:Costs and Cost Analysis; D005112:Extracorporeal Circulation; D006801:Humans; D007372:Interferons; D007694:Killer Cells, Natural; D008545:Melanoma; D013997:Time Factors',
#    'publication_types': "D016428:Journal Article; D013485:Research Support, Non-U.S. Gov't",
#    'chemical_list': 'D007372:Interferons',
#    'keywords': '',
#    'doi': '',
#    'references': '',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Arzneimittelforschung',
#    'nlm_unique_id': '0372660',
#    'issn_linking': '0004-4172',
#    'country': 'Germany'},
#   0.0),
#  ({'title': "[Method of determination of proteins with Coomassie brilliant blue G 250. I. General characteristics and comparative analysis with the biuret method and Lowry's method].",
#    'issue': '56(2)',
#    'pages': '160-5',
#    'abstract': "Bradford (1977) described a new sensitive easy rapid method for protein assay, depending on colour change of the stain Coomassie Brilliant Blue G 250. In this study Bradford's method was compared with the Lowry et al. 91951) and biuret methods. Coomassie method appears to be as sensitive as Lowry, as simple as biuret. Another advantage is a very short time of performing.",
#    'journal': 'Bollettino della Societa italiana di biologia sperimentale',
#    'authors': 'Serra|S|S|;Morgante|L|L|',
#    'pubdate': '1980',
#    'pmid': '6159906',
#    'mesh_terms': 'D008722:Methods; D011506:Proteins; D012710:Serum Albumin, Bovine; D013194:Staining and Labeling',
#    'publication_types': 'D003160:Comparative Study; D016428:Journal Article',
#    'chemical_list': 'D011506:Proteins; D012710:Serum Albumin, Bovine',
#    'keywords': '',
#    'doi': '',
#    'references': '',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Boll Soc Ital Biol Sper',
#    'nlm_unique_id': '7506962',
#    'issn_linking': '0037-8771',
#    'country': 'Italy'},
#   0.0),
#  ({'title': '[Method of determination of proteins with Coomassie brilliant blue G 250. II. Influence of pH and inorganic ions].',
#    'issue': '56(2)',
#    'pages': '166-70',
#    'abstract': 'The influences of pH and inorganic ions on the protein assay method of Bradford were investigated. Absorbance of bovine serum albumine appears to be increasing with the increase of pH. This effect is consistent with the hypothesis of Reissner et al. (1975), that colour change of the stain is a function of hydrogen ion concentration, but acquires statistical significance only for extreme basic pH. Among the tested inorganic ions, only Fe++ and NH4+ shows some interference. These dysadvantages could be corrected by appropriate blanks.',
#    'journal': 'Bollettino della Societa italiana di biologia sperimentale',
#    'authors': 'Serra|S|S|;Morgante|L|L|',
#    'pubdate': '1980',
#    'pmid': '6159907',
#    'mesh_terms': 'D006863:Hydrogen-Ion Concentration; D008722:Methods; D009994:Osmolar Concentration; D011506:Proteins; D012710:Serum Albumin, Bovine; D012996:Solutions; D013194:Staining and Labeling',
#    'publication_types': 'D016428:Journal Article',
#    'chemical_list': 'D011506:Proteins; D012996:Solutions; D012710:Serum Albumin, Bovine',
#    'keywords': '',
#    'doi': '',
#    'references': '',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Boll Soc Ital Biol Sper',
#    'nlm_unique_id': '7506962',
#    'issn_linking': '0037-8771',
#    'country': 'Italy'},
#   0.0),
#  ({'title': "[Clinical significance of pyridoxine administration in L-dopa therapy of Parkinsonism (author's transl)].",
#    'issue': '32(10)',
#    'pages': '991-1000',
#    'abstract': '',
#    'journal': 'No to shinkei = Brain and nerve',
#    'authors': 'Namba|S|S|;Ishimitsu|H|H|;Nakasone|S|S|',
#    'pubdate': '1980',
#    'pmid': '6159908',
#    'mesh_terms': 'D000328:Adult; D000368:Aged; D000818:Animals; D001923:Brain Chemistry; D002262:Carboxy-Lyases; D004298:Dopamine; D004359:Drug Therapy, Combination; D005260:Female; D006801:Humans; D006897:Hydroxyindoleacetic Acid; D007980:Levodopa; D008297:Male; D008875:Middle Aged; D010300:Parkinson Disease; D011736:Pyridoxine; D051381:Rats',
#    'publication_types': 'D002363:Case Reports; D004740:English Abstract; D016428:Journal Article',
#    'chemical_list': 'D007980:Levodopa; D006897:Hydroxyindoleacetic Acid; D002262:Carboxy-Lyases; D011736:Pyridoxine; D004298:Dopamine',
#    'keywords': '',
#    'doi': '',
#    'references': '',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'No To Shinkei',
#    'nlm_unique_id': '0413550',
#    'issn_linking': '0006-8969',
#    'country': 'Japan'},
#   0.0),
#  ({'title': 'Solubility and distribution of halothane in human blood.',
#    'issue': '52(9)',
#    'pages': '851-62',
#    'abstract': 'The interactions of halothane with five major constituents of human blood were studied by equilibrium dialysis. Haemoglobin, albumin, red cell membranes and triglycerides were found to contribute significantly to the solubility, and thus the transport, of halothane in whole blood. At physiological concentrations, gamma-globulin had no detectable effect on the solubility of halothane. Absorption isotherms of halothane binding to haemoglobin and albumin suggest a possible positive co-operative effect, but complete saturation of the binding sites was not observed even when the aqueous phase was saturated with halothane. The number of halothane molecules bound per albumin molecule was not significantly affected by the presence of oleic acid. For red cell ghosts and triglyceride-rich micelles (chylomicrons and very low density lipoprotein), the adsorption isotherms suggested that halothane is solubilized within the hydrophobic regions. The distribution of halothane between cells and plasma calculated from the above equilibrium dialysis results was in reasonable agreement with the distribution in whole blood determined by an independent method.',
#    'journal': 'British journal of anaesthesia',
#    'authors': 'Pang|Y C|YC|;Reid|P E|PE|;Brooks|D E|DE|',
#    'pubdate': '1980',
#    'pmid': '6159909',
#    'mesh_terms': 'D000042:Absorption; D000327:Adsorption; D002914:Chylomicrons; D003956:Dialysis; D004910:Erythrocyte Membrane; D006221:Halothane; D006454:Hemoglobins; D006801:Humans; D008079:Lipoproteins, VLDL; D012709:Serum Albumin; D012995:Solubility; D005719:gamma-Globulins',
#    'publication_types': "D016428:Journal Article; D013485:Research Support, Non-U.S. Gov't",
#    'chemical_list': 'D002914:Chylomicrons; D006454:Hemoglobins; D008079:Lipoproteins, VLDL; D012709:Serum Albumin; D005719:gamma-Globulins; D006221:Halothane',
#    'keywords': '',
#    'doi': '10.1093/bja/52.9.851',
#    'references': '',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Br J Anaesth',
#    'nlm_unique_id': '0372541',
#    'issn_linking': '0007-0912',
#    'country': 'England'},
#   0.0),
#  ({'title': 'Serum beta 2-microglobulin in myelomatosis: potential value in stratification and monitoring.',
#    'issue': '42(4)',
#    'pages': '510-5',
#    'abstract': 'In a longitudinal study of the evolution of serum beta 2-microglobulin (beta 2-m) levels in 37 patients with myelomatosis, those patients with a level of < 4 mg/l at first presentation had a median survival of 46 months, whereas those with an initial level of > mg/l had a median survival of 15 months. THe beta 2-m appeared to be independent of the level of the paraprotein and its class, as seen in a vertical study of 129 patients. Analysis of the influence of a rising serum creatinine on the serum beta 2-m indicates that beta 2-m production is excessive in advanced disease with or without renal failure. Practical application of the measurement of serum beta 2-m in the stratification and monitoring of patients is suggested.',
#    'journal': 'British journal of cancer',
#    'authors': 'Norfolk|D|D|;Child|J A|JA|;Cooper|E H|EH|;Kerruish|S|S|;Ward|A M|AM|',
#    'pubdate': '1980',
#    'pmid': '6159910',
#    'mesh_terms': 'D001609:Beta-Globulins; D003404:Creatinine; D004739:England; D005260:Female; D006801:Humans; D007070:Immunoglobulin A; D007074:Immunoglobulin G; D008137:Longitudinal Studies; D008297:Male; D008875:Middle Aged; D009101:Multiple Myeloma; D011379:Prognosis; D001613:beta 2-Microglobulin',
#    'publication_types': "D016428:Journal Article; D013485:Research Support, Non-U.S. Gov't",
#    'chemical_list': 'D001609:Beta-Globulins; D007070:Immunoglobulin A; D007074:Immunoglobulin G; D001613:beta 2-Microglobulin; D003404:Creatinine',
#    'keywords': '',
#    'doi': '10.1038/bjc.1980.273',
#    'references': '4134761;1175123;1182674;57015;23482;83581;465365',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Br J Cancer',
#    'nlm_unique_id': '0370635',
#    'issn_linking': '0007-0920',
#    'country': 'England'},
#   0.0),
#  ({'title': 'Effect of sodium butyrate on synthesis of specific proteins by human breast-carcinoma cells.',
#    'issue': '42(4)',
#    'pages': '616-9',
#    'abstract': '',
#    'journal': 'British journal of cancer',
#    'authors': 'Grieve|R J|RJ|;Woods|K L|KL|;Mann|P R|PR|;Smith|S C|SC|;Wilson|G D|GD|;Howell|A|A|',
#    'pubdate': '1980',
#    'pmid': '6159911',
#    'mesh_terms': 'D001943:Breast Neoplasms; D002087:Butyrates; D002272:Carcinoembryonic Antigen; D002452:Cell Count; D002460:Cell Line; D006063:Chorionic Gonadotropin; D015292:Glycoprotein Hormones, alpha Subunit; D006801:Humans; D007768:Lactalbumin; D008854:Microscopy, Electron; D009363:Neoplasm Proteins; D010446:Peptide Fragments',
#    'publication_types': "D016428:Journal Article; D013485:Research Support, Non-U.S. Gov't",
#    'chemical_list': 'D002087:Butyrates; D002272:Carcinoembryonic Antigen; D006063:Chorionic Gonadotropin; D015292:Glycoprotein Hormones, alpha Subunit; D009363:Neoplasm Proteins; D010446:Peptide Fragments; D007768:Lactalbumin',
#    'keywords': '',
#    'doi': '10.1038/bjc.1980.287',
#    'references': '4758660;4357887;1188362;2548;1250386;859583;799907;140761;876359;560263;196218;200351;22554;212193;421715;570644;471049;92331;389635',
#    'delete': False,
#    'affiliations': '',
#    'pmc': '',
#    'other_id': '',
#    'medline_ta': 'Br J Cancer',
#    'nlm_unique_id': '0370635',
#    'issn_linking': '0007-0920',
#    'country': 'England'},
#   0.0)]
