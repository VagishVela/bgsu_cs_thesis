# %%
import pubmed_parser as pp
import pandas as pd
import nltk
nltk.download('punkt')
import numpy as np
from csv import DictWriter
import json
import math

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity



#NLP 
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import en_core_sci_lg
import string

from tqdm import tqdm

tqdm.pandas()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vagishvela/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Get a sample of data from raw, and then ready the first file for analysis. Mostly because this computer isn't fast enough or large enough to do the whole analysis at once.

# %%
path_xml = pp.list_xml_path('../../data/raw') # list all xml paths under directory
pubmed_dict = pp.parse_medline_xml(path_xml[0]) # dictionary output

# %% [markdown]
# Let's checkout out what the data looks like.

# %%
df = pd.DataFrame(pubmed_dict)
df.head()
# Out:
#                                                title   issue   pages abstract  \
# 0  [Beta-blockers and arterial hypertension in th...   7(31)  2807-9
# 1  [beta-blockers and high risk pregnancies. View...   7(31)  2811-2
# 2  [Surface defense mechanisms of the nasal mucosa].  33(35)  1391-3
# 3   [Pharmacological treatment of coronary disease].  33(44)  1721-4
# 4             Treating the outpatient schizophrenic.   64(5)   48-56
#
#                                             journal  \
# 0                       La Nouvelle presse medicale
# 1                       La Nouvelle presse medicale
# 2  Polski tygodnik lekarski (Warsaw, Poland : 1960)
# 3  Polski tygodnik lekarski (Warsaw, Poland : 1960)
# 4                             Postgraduate medicine
#
#                        authors pubdate   pmid  \
# 0             Tcherdakoff|P|P|    1978  30970
# 1  Dubois|D|D|;Petitcolas|J|J|    1978  30971
# 2   Makowska|W|W|;Zawisza|E|E|    1978  30972
# 3             Krotkiewski|A|A|    1978  30973
# 4            Gelenberg|A J|AJ|    1978  30974
#
#                                           mesh_terms  \
# 0  D000319:Adrenergic beta-Antagonists; D005260:F...
# 1  D000070:Acebutolol; D000319:Adrenergic beta-An...
# 2  D001424:Bacterial Infections; D002633:Chemotax...
# 3  D000319:Adrenergic beta-Antagonists; D003327:C...
# 4  D000208:Acute Disease; D000553:Ambulatory Care...
#
#                          publication_types  ...  \
# 0                  D016428:Journal Article  ...
# 1                  D016428:Journal Article  ...
# 2  D016428:Journal Article; D016454:Review  ...
# 3                  D016428:Journal Article  ...
# 4                  D016428:Journal Article  ...
#
#                               doi references delete affiliations  pmc  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4  10.1080/00325481.1978.11714969             False
#
#   other_id       medline_ta nlm_unique_id issn_linking  country
# 0           Nouv Presse Med       0312552    0301-1518   France
# 1           Nouv Presse Med       0312552    0301-1518   France
# 2               Pol Tyg Lek       9705468    0032-3756   Poland
# 3               Pol Tyg Lek       9705468    0032-3756   Poland
# 4              Postgrad Med       0401147    0032-5481  England
#
# [5 rows x 22 columns]

# %% [markdown]
# Looks like all the data is there, or is it?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              30000 non-null  object
#  1   issue              30000 non-null  object
#  2   pages              30000 non-null  object
#  3   abstract           30000 non-null  object
#  4   journal            30000 non-null  object
#  5   authors            30000 non-null  object
#  6   pubdate            30000 non-null  object
#  7   pmid               30000 non-null  object
#  8   mesh_terms         30000 non-null  object
#  9   publication_types  30000 non-null  object
#  10  chemical_list      30000 non-null  object
#  11  keywords           30000 non-null  object
#  12  doi                30000 non-null  object
#  13  references         30000 non-null  object
#  14  delete             30000 non-null  bool
#  15  affiliations       30000 non-null  object
#  16  pmc                30000 non-null  object
#  17  other_id           30000 non-null  object
#  18  medline_ta         30000 non-null  object
#  19  nlm_unique_id      30000 non-null  object
#  20  issn_linking       30000 non-null  object
#  21  country            30000 non-null  object
# dtypes: bool(1), object(21)
# memory usage: 4.8+ MB

# %% [markdown]
# Let's drop the empty strings, as this data doesn't respond to `.isnull` or `.isna` methods.

# %%
abstractDf = df.drop(df[df['abstract'] == ''].index)

# %% [markdown]
# Now we have data that has abstracts, and we can start to do some analysis.

# %%
abstractDf
# Out:
#                                                    title    issue   pages  \
# 10     [Isolation and properties of preparations the ...    14(5)   683-9
# 11     Potentiation of apomorphine action in rats by ...     9(3)   375-8
# 14     Specific immune recognition by lymphocytes: an...    53(3)  225-41
# 19     An analysis of measured and calculated calcium...    38(7)  659-67
# 20     The value of immunoelectroosmophoresis (IEOP) ...    10(3)   173-6
# ...                                                  ...      ...     ...
# 29964                      Pregnancy hepatitis in Libya.  2(7990)   827-9
# 29965  Oral methionine in the treatment of severe par...  2(7990)  829-30
# 29966  Integrated concentrations of catecholamines in...  2(7990)   830-1
# 29967  The neurology of vitamin B12 deficiency. Metab...  2(7990)   832-3
# 29977  Measuring partial thromboplastin-time. An inte...  2(7990)   842-6
#
#                                                 abstract  \
# 10     The paper describes a modified method of isola...
# 11     Although the antiparkinsonian activity of 1-pr...
# 14     In this review, we analyze data pertinent to t...
# 19     Potentiometrically measured ionized calcium (C...
# 20     Immunoelectroosmophoresis (IEOP) has been used...
# ...                                                  ...
# 29964  The death-rate from hepatitis in pregnant wome...
# 29965  30 patients at risk of hepatic damage from par...
# 29966  The measurement of integrated concentrations o...
# 29967  The widely held view that the neurological and...
# 29977  A series of collaborative exercises on the par...
#
#                                                  journal  \
# 10               Prikladnaia biokhimiia i mikrobiologiia
# 11              Pharmacology, biochemistry, and behavior
# 14                       The Quarterly review of biology
# 19     Scandinavian journal of clinical and laborator...
# 20           Scandinavian journal of infectious diseases
# ...                                                  ...
# 29964                           Lancet (London, England)
# 29965                           Lancet (London, England)
# 29966                           Lancet (London, England)
# 29967                           Lancet (London, England)
# 29977                           Lancet (London, England)
#
#                                                  authors pubdate   pmid  \
# 10                      Shvedova|T A|TA|;Petrova|A N|AN|    1978  30978
# 11      Kostrzewa|R M|RM|;Kastin|A J|AJ|;Sobrian|S K|SK|    1978  30981
# 14                      Warr|G W|GW|;Marchalonis|J J|JJ|    1978  30984
# 19                                      Pedersen|K O|KO|    1978  30989
# 20             Wiernik|A|A|;Jarstrand|C|C|;Tunevall|G|G|    1978  30990
# ...                                                  ...     ...    ...
# 29964  Christie|A B|AB|;Allam|A A|AA|;Aref|M K|MK|;Mu...    1976  61499
# 29965  Crome|P|P|;Vale|J A|JA|;Volans|G N|GN|;Widdop|...    1976  61500
# 29966                                       Daggett|P|P|    1976  61501
# 29967                                   Reynolds|E H|EH|    1976  61502
# 29977                        Poller|L|L|;Thomson|J M|JM|    1976  61512
#
#                                               mesh_terms  \
# 10     D015061:1,4-alpha-Glucan Branching Enzyme; D00...
# 11     D000818:Animals; D001058:Apomorphine; D001522:...
# 14     D000220:Adaptation, Biological; D000818:Animal...
# 19     D000293:Adolescent; D000328:Adult; D000367:Age...
# 20     D000900:Anti-Bacterial Agents; D000942:Antigen...
# ...                                                  ...
# 29964  D000293:Adolescent; D000328:Adult; D005260:Fem...
# 29965  D000082:Acetaminophen; D000284:Administration,...
# 29966  D000310:Adrenal Gland Neoplasms; D001794:Blood...
# 29967  D000752:Anemia, Pernicious; D005492:Folic Acid...
# 29977  D001778:Blood Coagulation Disorders; D001780:B...
#
#                                        publication_types  ...  \
# 10     D003160:Comparative Study; D004740:English Abs...  ...
# 11     D003160:Comparative Study; D016428:Journal Art...  ...
# 14     D016428:Journal Article; D013487:Research Supp...  ...
# 19                               D016428:Journal Article  ...
# 20                               D016428:Journal Article  ...
# ...                                                  ...  ...
# 29964  D003160:Comparative Study; D016428:Journal Art...  ...
# 29965  D003160:Comparative Study; D016428:Journal Art...  ...
# 29966                            D016428:Journal Article  ...
# 29967                            D016428:Journal Article  ...
# 29977  D003160:Comparative Study; D016428:Journal Art...  ...
#
#                                   doi references delete affiliations  pmc  \
# 10                                                False
# 11       10.1016/0091-3057(78)90299-x             False
# 14                     10.1086/410621             False
# 19          10.3109/00365517809102433             False
# 20     10.3109/inf.1978.10.issue-3.03             False
# ...                               ...        ...    ...          ...  ...
# 29964   10.1016/s0140-6736(76)91210-1             False
# 29965   10.1016/s0140-6736(76)91211-3             False
# 29966   10.1016/s0140-6736(76)91212-5             False
# 29967   10.1016/s0140-6736(76)91213-7             False
# 29977   10.1016/s0140-6736(76)91224-1             False
#
#                other_id               medline_ta nlm_unique_id issn_linking  \
# 10                       Prikl Biokhim Mikrobiol       0023416    0555-1099
# 11                       Pharmacol Biochem Behav       0367050    0091-3057
# 14                                    Q Rev Biol       0376515    0033-5770
# 19                       Scand J Clin Lab Invest       0404375    0036-5513
# 20                            Scand J Infect Dis       0215333    0036-5548
# ...                 ...                      ...           ...          ...
# 29964  054851; 00198778                   Lancet      2985213R    0140-6736
# 29965                                     Lancet      2985213R    0140-6736
# 29966                                     Lancet      2985213R    0140-6736
# 29967                                     Lancet      2985213R    0140-6736
# 29977                                     Lancet      2985213R    0140-6736
#
#                    country
# 10     Russia (Federation)
# 11           United States
# 14           United States
# 19                 England
# 20                 England
# ...                    ...
# 29964              England
# 29965              England
# 29966              England
# 29967              England
# 29977              England
#
# [13415 rows x 22 columns]

# %%
string.punctuation
stopwords = list(STOP_WORDS)

# %%
stopwords
# Out:
# ['except',
#  'hence',
#  'keep',
#  'for',
#  'both',
#  'everywhere',
#  'formerly',
#  'whom',
#  'became',
#  'twenty',
#  "'ve",
#  'against',
#  'under',
#  'hundred',
#  'below',
#  'top',
#  'becoming',
#  'serious',
#  'was',
#  'seemed',
#  '’re',
#  'them',
#  'bottom',
#  'its',
#  'we',
#  'am',
#  'too',
#  'until',
#  'always',
#  'noone',
#  'such',
#  'sometime',
#  'during',
#  'latter',
#  'thence',
#  'becomes',
#  'our',
#  'thereupon',
#  'all',
#  'about',
#  'n’t',
#  'also',
#  'fifty',
#  'without',
#  'ever',
#  'namely',
#  'were',
#  'very',
#  'wherever',
#  'up',
#  'each',
#  'n‘t',
#  'which',
#  'first',
#  'one',
#  'various',
#  'toward',
#  'my',
#  'most',
#  'sixty',
#  'after',
#  'it',
#  'may',
#  'above',
#  'since',
#  'if',
#  'used',
#  'twelve',
#  'regarding',
#  'therein',
#  'sometimes',
#  'nor',
#  'him',
#  'from',
#  'himself',
#  '‘m',
#  'upon',
#  'either',
#  'a',
#  'become',
#  'almost',
#  'two',
#  'down',
#  'they',
#  'me',
#  'he',
#  'per',
#  'made',
#  'you',
#  'others',
#  "'s",
#  'through',
#  'unless',
#  'however',
#  'wherein',
#  'only',
#  'four',
#  'why',
#  'side',
#  'otherwise',
#  'mostly',
#  'get',
#  'anyway',
#  'along',
#  'elsewhere',
#  'be',
#  'just',
#  'give',
#  'while',
#  'enough',
#  'besides',
#  'several',
#  'anything',
#  'the',
#  '‘ll',
#  'herself',
#  'will',
#  'via',
#  'might',
#  'take',
#  'every',
#  'their',
#  'when',
#  'beyond',
#  'herein',
#  'and',
#  'few',
#  "'d",
#  'does',
#  'yet',
#  'something',
#  'call',
#  'whenever',
#  "n't",
#  'using',
#  'his',
#  'cannot',
#  'put',
#  'over',
#  'eight',
#  'next',
#  'please',
#  'onto',
#  'some',
#  'between',
#  'well',
#  'itself',
#  'being',
#  'would',
#  'say',
#  'ours',
#  'doing',
#  'else',
#  'here',
#  'hereupon',
#  'nevertheless',
#  'there',
#  'amongst',
#  'have',
#  'myself',
#  'whereas',
#  'around',
#  'us',
#  'beside',
#  'perhaps',
#  "'m",
#  'yourself',
#  'within',
#  '‘s',
#  'meanwhile',
#  'thus',
#  'everything',
#  'into',
#  'where',
#  'forty',
#  'although',
#  'of',
#  'behind',
#  'are',
#  'thereby',
#  'quite',
#  'even',
#  'thru',
#  'same',
#  'name',
#  'due',
#  'had',
#  'must',
#  'seeming',
#  'show',
#  'whole',
#  '‘re',
#  '’ve',
#  'anywhere',
#  'whoever',
#  'an',
#  'nowhere',
#  'yourselves',
#  'rather',
#  'somehow',
#  'empty',
#  'full',
#  'ten',
#  'amount',
#  '‘d',
#  'much',
#  'should',
#  'has',
#  'less',
#  'once',
#  'do',
#  'former',
#  're',
#  'or',
#  'therefore',
#  'another',
#  'before',
#  'though',
#  'done',
#  'whatever',
#  'towards',
#  'whose',
#  'indeed',
#  'own',
#  'ourselves',
#  'move',
#  'anyhow',
#  'by',
#  'these',
#  'latterly',
#  'whither',
#  'been',
#  'with',
#  '’ll',
#  'see',
#  'fifteen',
#  'not',
#  'hereafter',
#  '‘ve',
#  'never',
#  "'re",
#  'off',
#  'whereby',
#  'no',
#  'least',
#  'this',
#  'more',
#  'then',
#  'hers',
#  'whence',
#  'what',
#  'among',
#  'because',
#  'six',
#  'your',
#  'themselves',
#  '’s',
#  'afterwards',
#  'on',
#  'three',
#  'those',
#  'in',
#  'third',
#  'whereafter',
#  'alone',
#  'somewhere',
#  "'ll",
#  'further',
#  'make',
#  '’m',
#  'how',
#  'than',
#  'did',
#  'last',
#  'together',
#  'but',
#  'across',
#  'really',
#  'anyone',
#  'front',
#  'could',
#  'moreover',
#  'ca',
#  'nothing',
#  'yours',
#  'five',
#  'many',
#  'i',
#  'whether',
#  'that',
#  'none',
#  'throughout',
#  'to',
#  'seem',
#  'any',
#  'go',
#  'back',
#  'nobody',
#  'part',
#  'often',
#  'other',
#  '’d',
#  'again',
#  'mine',
#  'hereby',
#  'at',
#  'eleven',
#  'still',
#  'seems',
#  'so',
#  'as',
#  'already',
#  'her',
#  'beforehand',
#  'she',
#  'everyone',
#  'out',
#  'someone',
#  'can',
#  'thereafter',
#  'whereupon',
#  'who',
#  'now',
#  'is',
#  'neither',
#  'nine']

# %%
def tokenizer(text):
    parser = en_core_sci_lg.load()
    tokens = parser(text)
    tokens = [token.lemma_.lower().strip() for token in tokens if token.lemma_ != '-PRON-']
    tokens = [token for token in tokens if token not in stopwords and token not in string.punctuation]
    return tokens

# %%
abstractDf['processed_abstract'] = abstractDf['abstract'].apply(tokenizer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/vagishvela/Projects/BGSU/bgsu_cs_thesis/notebooks/analysis/classification.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/vagishvela/Projects/BGSU/bgsu_cs_thesis/notebooks/analysis/classification.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> abstractDf['processed_abstract'] = abstractDf['abstract'].apply(tokenizer)
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/pandas/core/apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/pandas/core/apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# /Users/vagishvela/Projects/BGSU/bgsu_cs_thesis/notebooks/analysis/classification.ipynb Cell 15 in tokenizer(text)
#       <a href='vscode-notebook-cell:/Users/vagishvela/Projects/BGSU/bgsu_cs_thesis/notebooks/analysis/classification.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> def tokenizer(text):
# ----> <a href='vscode-notebook-cell:/Users/vagishvela/Projects/BGSU/bgsu_cs_thesis/notebooks/analysis/classification.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a>     parser = en_core_sci_lg.load()
#       <a href='vscode-notebook-cell:/Users/vagishvela/Projects/BGSU/bgsu_cs_thesis/notebooks/analysis/classification.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>     tokens = parser(text)
#       <a href='vscode-notebook-cell:/Users/vagishvela/Projects/BGSU/bgsu_cs_thesis/notebooks/analysis/classification.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>     tokens = [token.lemma_.lower().strip() for token in tokens if token.lemma_ != '-PRON-']
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/en_core_sci_lg/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/spacy/util.py:649, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     647 if not model_path.exists():
#     648     raise IOError(Errors.E052.format(path=data_path))
# --> 649 return load_model_from_path(
#     650     data_path,
#     651     vocab=vocab,
#     652     meta=meta,
#     653     disable=disable,
#     654     enable=enable,
#     655     exclude=exclude,
#     656     config=config,
#     657 )
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/spacy/util.py:514, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     505 config = load_config(config_path, overrides=overrides)
#     506 nlp = load_model_from_config(
#     507     config,
#     508     vocab=vocab,
#    (...)
#     512     meta=meta,
#     513 )
# --> 514 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/spacy/language.py:2147, in Language.from_disk(self, path, exclude, overrides)
#    2144 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2145     # Convert to list here in case exclude is (default) tuple
#    2146     exclude = list(exclude) + ["vocab"]
# -> 2147 util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2148 self._path = path  # type: ignore[assignment]
#    2149 self._link_components()
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/spacy/util.py:1352, in from_disk(path, readers, exclude)
#    1349 for key, reader in readers.items():
#    1350     # Split to support file names like meta.json
#    1351     if key.split(".")[0] not in exclude:
# -> 1352         reader(path / key)
#    1353 return path
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/spacy/language.py:2123, in Language.from_disk.<locals>.deserialize_vocab(path)
#    2121 def deserialize_vocab(path: Path) -> None:
#    2122     if path.exists():
# -> 2123         self.vocab.from_disk(path, exclude=exclude)
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/spacy/vocab.pyx:492, in spacy.vocab.Vocab.from_disk()
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/spacy/vectors.pyx:620, in spacy.vectors.Vectors.from_disk()
#
# File ~/Projects/BGSU/bgsu_cs_thesis/.venv/lib/python3.9/site-packages/spacy/util.py:1343, in from_disk(path, readers, exclude)
#    1339             writer(path / key)
#    1340     return path
# -> 1343 def from_disk(
#    1344     path: Union[str, Path],
#    1345     readers: Dict[str, Callable[[Path], None]],
#    1346     exclude: Iterable[str],
#    1347 ) -> Path:
#    1348     path = ensure_path(path)
#    1349     for key, reader in readers.items():
#    1350         # Split to support file names like meta.json
#
# KeyboardInterrupt:

# %%
abstractDf
