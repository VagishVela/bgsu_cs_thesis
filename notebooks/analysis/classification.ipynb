# %%
import pubmed_parser as pp
import pandas as pd
import nltk
nltk.download('punkt')
import numpy as np
from csv import DictWriter
import json
import math

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity



#NLP 
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import en_core_sci_lg
import string

from tqdm import tqdm
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vagishvela/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Get a sample of data from raw, and then ready the first file for analysis. Mostly because this computer isn't fast enough or large enough to do the whole analysis at once.

# %%
path_xml = pp.list_xml_path('../../data/raw') # list all xml paths under directory
pubmed_dict = pp.parse_medline_xml(path_xml[0]) # dictionary output

# %% [markdown]
# Let's checkout out what the data looks like.

# %%
df = pd.DataFrame(pubmed_dict)
df.head()
# Out:
#                                                title   issue   pages abstract  \
# 0  [Beta-blockers and arterial hypertension in th...   7(31)  2807-9
# 1  [beta-blockers and high risk pregnancies. View...   7(31)  2811-2
# 2  [Surface defense mechanisms of the nasal mucosa].  33(35)  1391-3
# 3   [Pharmacological treatment of coronary disease].  33(44)  1721-4
# 4             Treating the outpatient schizophrenic.   64(5)   48-56
#
#                                             journal  \
# 0                       La Nouvelle presse medicale
# 1                       La Nouvelle presse medicale
# 2  Polski tygodnik lekarski (Warsaw, Poland : 1960)
# 3  Polski tygodnik lekarski (Warsaw, Poland : 1960)
# 4                             Postgraduate medicine
#
#                        authors pubdate   pmid  \
# 0             Tcherdakoff|P|P|    1978  30970
# 1  Dubois|D|D|;Petitcolas|J|J|    1978  30971
# 2   Makowska|W|W|;Zawisza|E|E|    1978  30972
# 3             Krotkiewski|A|A|    1978  30973
# 4            Gelenberg|A J|AJ|    1978  30974
#
#                                           mesh_terms  \
# 0  D000319:Adrenergic beta-Antagonists; D005260:F...
# 1  D000070:Acebutolol; D000319:Adrenergic beta-An...
# 2  D001424:Bacterial Infections; D002633:Chemotax...
# 3  D000319:Adrenergic beta-Antagonists; D003327:C...
# 4  D000208:Acute Disease; D000553:Ambulatory Care...
#
#                          publication_types  ...  \
# 0                  D016428:Journal Article  ...
# 1                  D016428:Journal Article  ...
# 2  D016428:Journal Article; D016454:Review  ...
# 3                  D016428:Journal Article  ...
# 4                  D016428:Journal Article  ...
#
#                               doi references delete affiliations  pmc  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4  10.1080/00325481.1978.11714969             False
#
#   other_id       medline_ta nlm_unique_id issn_linking  country
# 0           Nouv Presse Med       0312552    0301-1518   France
# 1           Nouv Presse Med       0312552    0301-1518   France
# 2               Pol Tyg Lek       9705468    0032-3756   Poland
# 3               Pol Tyg Lek       9705468    0032-3756   Poland
# 4              Postgrad Med       0401147    0032-5481  England
#
# [5 rows x 22 columns]

# %% [markdown]
# Looks like all the data is there, or is it?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              30000 non-null  object
#  1   issue              30000 non-null  object
#  2   pages              30000 non-null  object
#  3   abstract           30000 non-null  object
#  4   journal            30000 non-null  object
#  5   authors            30000 non-null  object
#  6   pubdate            30000 non-null  object
#  7   pmid               30000 non-null  object
#  8   mesh_terms         30000 non-null  object
#  9   publication_types  30000 non-null  object
#  10  chemical_list      30000 non-null  object
#  11  keywords           30000 non-null  object
#  12  doi                30000 non-null  object
#  13  references         30000 non-null  object
#  14  delete             30000 non-null  bool
#  15  affiliations       30000 non-null  object
#  16  pmc                30000 non-null  object
#  17  other_id           30000 non-null  object
#  18  medline_ta         30000 non-null  object
#  19  nlm_unique_id      30000 non-null  object
#  20  issn_linking       30000 non-null  object
#  21  country            30000 non-null  object
# dtypes: bool(1), object(21)
# memory usage: 4.8+ MB

# %% [markdown]
# Let's drop the empty strings, as this data doesn't respond to `.isnull` or `.isna` methods.

# %%
abstractDf = df.drop(df[df['abstract'] == ''].index)

# %% [markdown]
# Now we have data that has abstracts, and we can start to do some analysis.

# %%
abstractDf['abstract'].to_list()[0]
# Out:
# 'The paper describes a modified method of isolating the branching enzyme of amylose isomerase from muscles and a study of the enzyme activity at different stages of purification. By enzyme fractionation on biogel R-150 and Sepharose 6B the fractions containing different RNA amounts have been isolated. The activity of fractions has been shown to depend on their content of RNA. The paper presents a procedure used to isolate a highly purified fraction of amylose isomerase and its properties (pH and temperature optima, enzyme optimal concentration and Michaelis constant).'

# %%
abstractDf['mesh_terms'].to_list()[0]
# Out:
# 'D015061:1,4-alpha-Glucan Branching Enzyme; D000596:Amino Acids; D000818:Animals; D002384:Catalysis; D055598:Chemical Phenomena; D002621:Chemistry; D002850:Chromatography, Gel; D004591:Electrophoresis, Polyacrylamide Gel; D005964:Glucosyltransferases; D006863:Hydrogen-Ion Concentration; D007700:Kinetics; D008722:Methods; D009132:Muscles; D012313:RNA; D011817:Rabbits; D012685:Sepharose; D013696:Temperature'

# %% [markdown]
# ## Stopwords Section

# %%
string.punctuation
stopwords = list(STOP_WORDS)

# %%
stopwords
# Out:
# ['even',
#  'yourselves',
#  'one',
#  'until',
#  'eleven',
#  'fifty',
#  'just',
#  'myself',
#  'i',
#  'part',
#  'beforehand',
#  'therefore',
#  'seeming',
#  'would',
#  'except',
#  'then',
#  'towards',
#  'yourself',
#  'their',
#  'than',
#  'several',
#  'them',
#  'however',
#  'see',
#  'among',
#  'me',
#  'because',
#  'between',
#  'full',
#  'fifteen',
#  "'ve",
#  'around',
#  'moreover',
#  'call',
#  'for',
#  'of',
#  'after',
#  'you',
#  'alone',
#  'next',
#  'across',
#  'whole',
#  'yours',
#  'amount',
#  'other',
#  'two',
#  'whatever',
#  'became',
#  'in',
#  'keep',
#  'least',
#  'each',
#  'something',
#  'whereby',
#  "'m",
#  'your',
#  "'ll",
#  'rather',
#  'at',
#  'besides',
#  'further',
#  'still',
#  'on',
#  'third',
#  'who',
#  'where',
#  'she',
#  'an',
#  'a',
#  'whither',
#  'ever',
#  'how',
#  'these',
#  'mostly',
#  'must',
#  'anyway',
#  'say',
#  'himself',
#  'whereas',
#  'every',
#  'show',
#  'my',
#  'side',
#  'beside',
#  'whether',
#  'almost',
#  'seem',
#  'has',
#  'hereby',
#  'whenever',
#  'us',
#  'they',
#  'along',
#  'anyone',
#  'to',
#  'though',
#  '’d',
#  're',
#  'forty',
#  'his',
#  '‘ll',
#  '‘d',
#  'bottom',
#  'own',
#  'nor',
#  'everywhere',
#  "'re",
#  'used',
#  'if',
#  'any',
#  '’s',
#  'done',
#  'below',
#  'does',
#  'thus',
#  'under',
#  'when',
#  'serious',
#  'n’t',
#  'been',
#  'latter',
#  'first',
#  'really',
#  'hundred',
#  'often',
#  'ca',
#  'again',
#  'during',
#  'sixty',
#  'top',
#  'well',
#  'go',
#  'various',
#  'may',
#  'since',
#  'had',
#  'same',
#  'which',
#  'twenty',
#  'whence',
#  'otherwise',
#  'made',
#  'about',
#  'those',
#  'off',
#  'too',
#  'enough',
#  'make',
#  'not',
#  "'s",
#  'take',
#  'per',
#  'themselves',
#  'ourselves',
#  'hereafter',
#  "n't",
#  'becomes',
#  'up',
#  'could',
#  'also',
#  'from',
#  'he',
#  '’ll',
#  'six',
#  'everyone',
#  'and',
#  'such',
#  'hers',
#  'its',
#  'now',
#  '’m',
#  'everything',
#  'him',
#  'upon',
#  'indeed',
#  'should',
#  'give',
#  'nothing',
#  'latterly',
#  'whereafter',
#  'yet',
#  'through',
#  'ten',
#  'former',
#  'unless',
#  'more',
#  'what',
#  'our',
#  'wherein',
#  'move',
#  'anything',
#  'throughout',
#  'but',
#  'never',
#  'am',
#  'will',
#  'over',
#  'few',
#  'although',
#  'put',
#  'front',
#  'onto',
#  'sometime',
#  'or',
#  'regarding',
#  'thereafter',
#  'already',
#  'we',
#  'back',
#  'do',
#  'most',
#  'four',
#  'behind',
#  'hence',
#  '‘re',
#  'cannot',
#  'name',
#  'meanwhile',
#  'somewhere',
#  'eight',
#  'nobody',
#  'namely',
#  "'d",
#  'whom',
#  'five',
#  'no',
#  'many',
#  'therein',
#  'seems',
#  'whose',
#  'itself',
#  'her',
#  '’re',
#  'did',
#  'there',
#  'another',
#  'none',
#  'three',
#  'afterwards',
#  'together',
#  'quite',
#  'whoever',
#  'very',
#  'much',
#  'formerly',
#  'amongst',
#  'without',
#  'into',
#  'down',
#  'it',
#  '‘s',
#  'less',
#  'some',
#  'herself',
#  'seemed',
#  '‘ve',
#  'via',
#  'twelve',
#  'that',
#  '‘m',
#  'before',
#  'else',
#  'nowhere',
#  'mine',
#  'why',
#  'out',
#  'here',
#  'others',
#  'ours',
#  'thereupon',
#  'above',
#  'become',
#  'against',
#  'with',
#  'have',
#  'always',
#  'while',
#  'was',
#  'thereby',
#  'beyond',
#  'once',
#  'n‘t',
#  'please',
#  'is',
#  'someone',
#  'this',
#  'somehow',
#  'nine',
#  'were',
#  'thru',
#  'empty',
#  'due',
#  'so',
#  '’ve',
#  'wherever',
#  'as',
#  'be',
#  'being',
#  'elsewhere',
#  'either',
#  'by',
#  'all',
#  'using',
#  'becoming',
#  'noone',
#  'neither',
#  'might',
#  'within',
#  'thence',
#  'can',
#  'get',
#  'hereupon',
#  'anyhow',
#  'last',
#  'only',
#  'doing',
#  'herein',
#  'anywhere',
#  'toward',
#  'are',
#  'perhaps',
#  'sometimes',
#  'nevertheless',
#  'the',
#  'whereupon',
#  'both']

# %%
def tokenizer(text):
    parser = en_core_sci_lg.load()
    tokens = parser(text)
    # Remove stop words and punctuation symbols
    # tokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in tokens ]
    return tokens

# %%
abstract10Df = abstractDf.head(2)

# %%
tqdm.pandas()
abstract10Df['processed_abstract'] = abstract10Df['abstract'].apply(tokenizer)

# https://www.kaggle.com/code/maksimeren/covid-19-literature-clustering#Vectorization
# Out:
# /var/folders/tt/tm6_2g8s2ys845fjxspz_0wh0000gn/T/ipykernel_60845/573547843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abstract10Df['processed_abstract'] = abstract10Df['abstract'].apply(tokenizer)

# %%
text = ''
for token in abstract10Df['processed_abstract'].values[0]:
    text += token.text + ' '
text
# Out:
# 'The paper describes a modified method of isolating the branching enzyme of amylose isomerase from muscles and a study of the enzyme activity at different stages of purification . By enzyme fractionation on biogel R-150 and Sepharose 6B the fractions containing different RNA amounts have been isolated . The activity of fractions has been shown to depend on their content of RNA . The paper presents a procedure used to isolate a highly purified fraction of amylose isomerase and its properties ( pH and temperature optima , enzyme optimal concentration and Michaelis constant ) . '

# %%
abstract10Df['processed_abstract'].values.tolist()
# Out:
# [The paper describes a modified method of isolating the branching enzyme of amylose isomerase from muscles and a study of the enzyme activity at different stages of purification. By enzyme fractionation on biogel R-150 and Sepharose 6B the fractions containing different RNA amounts have been isolated. The activity of fractions has been shown to depend on their content of RNA. The paper presents a procedure used to isolate a highly purified fraction of amylose isomerase and its properties (pH and temperature optima, enzyme optimal concentration and Michaelis constant).,
#  Although the antiparkinsonian activity of 1-prolyl-l-leucyl-glycine amide (PLG=MIF-I) has been previously observed in several clinical trials, little is known of the mechanism of action of this tripeptide on the brain. Our study demonstrated potentiation of the action of apomorphine by PLG on the rotational behavior of mature rats which received unilateral 6-OHDA (16 microgram) lesions of the striatum as neonates. No change in tyrosine hydroxylase or dopa decarboxylase activities in rat striatal homogenates was found after addition of PLG (10(-8-10(-3) M). The results suggest that PLG modifies the dopamine receptor, making it more responsive to stimulation by the agonistic agent apomorphine and perhaps by the natural neurotransmitter dopamine.]

# %% [markdown]
# ## Vectorizer

# %%
tfidfvectorizer = TfidfVectorizer()

# %%
abstract10Df = abstractDf.head(10)

# %%
vectorized_abstracts = tfidfvectorizer.fit_transform(abstract10Df['abstract'].values)

# %%
vectorized_abstracts.shape
# Out:
# (10, 504)

# %%
features = tfidfvectorizer.get_feature_names_out()

# %%
features
# Out:
# array(['001', '01', '05', '10', '100', '105', '138', '14', '150', '16',
#        '160', '17', '224', '23', '243', '30', '32', '324', '36', '37',
#        '38', '41', '500', '57', '64', '69', '6b', '72', '76', '91', '95',
#        'about', 'acid', 'action', 'activated', 'activation', 'activities',
#        'activity', 'addition', 'affinity', 'after', 'agent', 'agonistic',
#        'albumin', 'all', 'also', 'although', 'amacrine', 'amide', 'among',
#        'amounts', 'amylose', 'an', 'analyze', 'anatomical', 'and',
#        'animals', 'antibiotics', 'antibodies', 'antibody', 'antigen',
#        'antiparkinsonian', 'any', 'apomorphine', 'apparent', 'apparently',
#        'appears', 'are', 'as', 'assay', 'assessed', 'associated', 'at',
#        'atenolol', 'auditory', 'authors', 'basic', 'be', 'beats',
#        'because', 'been', 'before', 'behavior', 'below', 'betablocking',
#        'binding', 'biochemical', 'biogel', 'blood', 'bound', 'brain',
#        'brainstem', 'branching', 'but', 'by', 'ca2', 'calcium',
#        'calculated', 'can', 'capable', 'carried', 'cases', 'cause',
#        'caused', 'cells', 'change', 'chloride', 'chromic', 'clinical',
#        'clinically', 'cochlear', 'cofactor', 'collected', 'combining',
#        'compared', 'competent', 'concentration', 'conclude', 'concluded',
#        'conclusions', 'concomitant', 'conformed', 'consider',
#        'considered', 'constant', 'containing', 'content', 'contribution',
#        'corrected', 'correlated', 'dark', 'data', 'day', 'decarboxylase',
#        'declined', 'decompensation', 'decreased', 'decreasing',
#        'degeneration', 'demonstrated', 'depend', 'describes', 'detect',
#        'detectable', 'diagnosis', 'diagnostic', 'diameter', 'diastolic',
#        'did', 'different', 'diminution', 'direct', 'disease', 'distinct',
#        'distribution', 'diverse', 'divisions', 'donors', 'dopa',
#        'dopamine', 'dose', 'drawn', 'due', 'during', 'earlier',
#        'echocardiographically', 'elisa', 'enddiastolic', 'enzyme',
#        'equation', 'especially', 'essential', 'essentially', 'evidence',
#        'existence', 'exposed', 'extent', 'eyes', 'failed', 'fall',
#        'fibers', 'findings', 'firing', 'fish', 'following', 'for',
#        'formation', 'formed', 'found', 'fraction', 'fractionation',
#        'fractions', 'frequency', 'frog', 'frogs', 'from', 'function',
#        'functional', 'gave', 'given', 'glutamate', 'glutamatergic',
#        'glycine', 'guinea', 'had', 'has', 'have', 'heart',
#        'hemagglutination', 'hg', 'highly', 'homogenates', 'hydroxylase',
#        'hypertension', 'hypoalbuminaemia', 'hypothesis', 'ieop', 'immune',
#        'immunity', 'immunocompetent', 'immunoelectroosmophoresis',
#        'immunoglobulins', 'immunologically', 'immunosorbent', 'improves',
#        'in', 'increase', 'increased', 'increasing', 'indirect',
#        'induction', 'infection', 'information', 'infused', 'initially',
#        'injected', 'input', 'insignificantly', 'instance', 'into',
#        'invertebrates', 'investigations', 'involved', 'ionized', 'is',
#        'isolate', 'isolated', 'isolating', 'isomerase', 'it', 'its',
#        'kainic', 'kcaalb', 'killed', 'known', 'later', 'law', 'left',
#        'lesions', 'less', 'leucyl', 'light', 'limit', 'linked', 'little',
#        'longterm', 'lower', 'lymphocytes', 'made', 'maintained', 'make',
#        'making', 'mammals', 'mass', 'mature', 'may', 'mean', 'measured',
#        'measurement', 'mechanism', 'mechanisms', 'mediated', 'membrane',
#        'method', 'mg', 'michaelis', 'microgram', 'mif', 'might', 'min',
#        'mm', 'modified', 'modifies', 'mol', 'more', 'most', 'muscles',
#        'mycoplasma', 'mycoplasmal', 'natural', 'neonates', 'nerve',
#        'neurons', 'neurotoxin', 'neurotransmitter', 'no', 'normal',
#        'normality', 'not', 'now', 'nucleus', 'observed', 'obtained',
#        'occurs', 'of', 'ohda', 'on', 'only', 'optima', 'optimal', 'or',
#        'orally', 'origins', 'other', 'our', 'out', 'overestimation',
#        'paper', 'particularly', 'patients', 'pattern', 'perhaps',
#        'perilymph', 'perilymphatic', 'pertinent', 'ph', 'phenomena',
#        'physicochemical', 'physiological', 'pigs', 'plg', 'pneumococcal',
#        'pneumococci', 'pneumonia', 'pneumoniae', 'polysaccharide',
#        'possess', 'potentiation', 'potentiometrically', 'practicable',
#        'presents', 'pressure', 'presynaptic', 'previously', 'primary',
#        'probability', 'procedure', 'processes', 'processing', 'produces',
#        'prolyl', 'properties', 'proteins', 'proven', 'provide',
#        'pteridine', 'purification', 'purified', 'putative', 'rapidity',
#        'rapidly', 'rarely', 'rat', 'rate', 'rats', 'received', 'receptor',
#        'recognition', 'red', 'reduction', 'reflected', 'regions',
#        'regulatory', 'remained', 'request', 'response', 'responsive',
#        'resulting', 'results', 'retinal', 'review', 'rise', 'rna', 'rose',
#        'rotational', 'routinely', 'sac', 'samples', 'satisfactory',
#        'secreted', 'seen', 'selective', 'sensitive', 'sepharose',
#        'serological', 'serologically', 'serum', 'several', 'severity',
#        'share', 'shortening', 'should', 'shown', 'significant', 'silence',
#        'similar', 'simple', 'since', 'single', 'sites', 'slight',
#        'slightly', 'sonication', 'sound', 'specific', 'specimens',
#        'spite', 'sputum', 'stage', 'stages', 'stimulation', 'striatal',
#        'striatum', 'strobe', 'studies', 'study', 'subjected',
#        'subsaturating', 'substance', 'substances', 'substitute',
#        'suggest', 'supports', 'surface', 'systems', 'systolic',
#        'temperature', 'test', 'than', 'that', 'the', 'their', 'therapy',
#        'there', 'these', 'they', 'this', 'those', 'though', 'throughout',
#        'times', 'to', 'too', 'total', 'transverse', 'treated',
#        'treatment', 'trials', 'tripeptide', 'type', 'tyrosine',
#        'unchanged', 'unilateral', 'units', 'unlikely', 'unreliable', 'up',
#        'used', 'useful', 'using', 'valuable', 'value', 'variable',
#        'ventricular', 'verified', 'vertebrate', 'vertebrates', 'very',
#        'visual', 'vitro', 'vivo', 'was', 'we', 'weeks', 'well', 'were',
#        'when', 'where', 'whereas', 'which', 'whom', 'with', 'work', 'yet'],
#       dtype=object)
